# %%
import conf
import requests,json,time
from boltiot import Bolt,Sms
API_KEY = "86d017cb-4e66-4bac-8151-487c4036339d"   # Bolt API Key
DEVICE_ID = "BOLT13166995" # Bolt Device ID
SID = 'ACdb3ccdf73b4b17149e2d1a70a1c9bb46' # Twilio Account SID
AUTH_TOKEN = 'f104be6f4e7edabc249eeb2e65dcdc72' #Twilio Auth Token
FROM_NUMBER = '+12057843419' # Twilio Trial Number
TO_NUMBER = '+919757171773' #Your own mobile number
mybolt=Bolt(API_KEY,DEVICE_ID)
sms1=Sms(SID,AUTH_TOKEN,TO_NUMBER,FROM_NUMBER)
def get_crypto_price(u):
    url="http://min-api.cryptocompare.com/data/price?fsym="+u+"&tsyms=INR"
    response=requests.request("GET",url)
    response=json.loads(response.text)
    current_price=response["INR"]
    return current_price
def crypto(z):
    print("Enter the rate of the crypto currency,you have purchase:")
    sp=float(input())
    m=0
    while True:
       y=get_crypto_price(z)
       ss=int(y)
       print("This is the current rate of "+z+" in INR")
       print(ss)
       p=(ss-sp)*(100/sp)
       p1=int(p)
       if(p1>=0):
           print("Your current Profit percent on the stock is ",p1)
       elif(p1<0):
           print("Your loss percent is",abs(p1))
       if 0<=p1<5:
          response=mybolt.digitalWrite("0","HIGH")
          print("the stock value is increased more than 1% higher than your rate:\n"+str(response))
       elif 5<=p1<10:
          response=mybolt.digitalWrite("1","HIGH")
          print("the stock value is increased more than 5% higher than your rate\n"+str(response))
       elif 10<=p1:
          response=sms1.send_sms("Cryptocurrency value is increased more than 10% kindly perform the needful exchange")
          print("the response from Twilio:\n"+str(response))
       elif p1==0 and sp<ss:
          response=mybolt.digitalWrite("0","HIGH")
          print("The stock value is just marginally higher than your rate\n",response)
       else:
          response=mybolt.digitalWrite("0","LOW")
          response=mybolt.digitalWrite("1","LOW")
          print("the prices of stock are not sufficient to exchange\n"+str(response))
       m+=1
       if m==5:
          print("Do you want to continue with same stock:(1/0)")
          s=int(input())
          if s==1:
             continue
          elif s==0:
             break
          else:
             print("Kindly choose 1 for yes and 0 for No")
             continue
       time.sleep(10)

while True:
  try:
     print("----------------------------------------------------------------------------------------------------------------------------------------------------------------")
     print("Welcome to Autonomus Cryptocurrency Exchange:")
     print("The variety of Crypto-currency Available for Autonomus Alert System are:")
     print("1.Bitcoin [BTC]\n2.Ethereum [ETH]\n3.EOS [EOS]\n4.Xrp [XRP]\n5.Litecoin [LTC]\n6.Okex [OKB]\n7.Tron [TRX]\nKindly choose your Crypto from 1-7")
     ch=int(input())
     if (ch==1):
          crypto("BTC")
     elif(ch==2):
          crypto("ETH")
     elif(ch==3):
          crypto("EOS")
     elif(ch==4):
          crypto("XRP")
     elif(ch==5):
          crypto("LTC")
     elif(ch==6):
          crypto("OKB")
     elif(ch==7):
          crypto("TRX")
     else:
         print("Kindly choose a correct option, the choosen currency is invalid")
  except exceptions as e:
     print("error:",e)
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Welcome to Autonomus Cryptocurrency Exchange:
# The variety of Crypto-currency Available for Autonomus Alert System are:
# 1.Bitcoin [BTC]
# 2.Ethereum [ETH]
# 3.EOS [EOS]
# 4.Xrp [XRP]
# 5.Litecoin [LTC]
# 6.Okex [OKB]
# 7.Tron [TRX]
# Kindly choose your Crypto from 1-7
# 2
# Enter the rate of the crypto currency,you have purchase:
# 29834
# This is the current rate of ETH in INR
# 30757
# Your current Profit percent on the stock is  3
# the stock value is increased more than 1% higher than your rate:
# {"value": "1", "success": 1}
# This is the current rate of ETH in INR
# 30757
# Your current Profit percent on the stock is  3
# the stock value is increased more than 1% higher than your rate:
# {"value": "1", "success": 1}
# This is the current rate of ETH in INR
# 30766
# Your current Profit percent on the stock is  3
# the stock value is increased more than 1% higher than your rate:
# {"value": "1", "success": 1}
# This is the current rate of ETH in INR
# 30766
# Your current Profit percent on the stock is  3
# the stock value is increased more than 1% higher than your rate:
# {"value": "1", "success": 1}
# This is the current rate of ETH in INR
# 30766
# Your current Profit percent on the stock is  3
# the stock value is increased more than 1% higher than your rate:
# {"value": "1", "success": 1}
# Do you want to continue with same stock:(1/0)
# 0
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Welcome to Autonomus Cryptocurrency Exchange:
# The variety of Crypto-currency Available for Autonomus Alert System are:
# 1.Bitcoin [BTC]
# 2.Ethereum [ETH]
# 3.EOS [EOS]
# 4.Xrp [XRP]
# 5.Litecoin [LTC]
# 6.Okex [OKB]
# 7.Tron [TRX]
# Kindly choose your Crypto from 1-7
# 3
# Enter the rate of the crypto currency,you have purchase:
# 1
# This is the current rate of EOS in INR
# 239
# Your current Profit percent on the stock is  23800
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SMa8a97f5fc046476482e15b49556a38e0>
# This is the current rate of EOS in INR
# 239
# Your current Profit percent on the stock is  23800
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SM9c5c2f2b2b6d43899851e16de4801f9b>
# This is the current rate of EOS in INR
# 239
# Your current Profit percent on the stock is  23800
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SM9324f4a480b146cfbb9bc0df2c9dc97a>
# This is the current rate of EOS in INR
# 239
# Your current Profit percent on the stock is  23800
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SM5898d58c77834ceba717733e651e8aad>
# This is the current rate of EOS in INR
# 239
# Your current Profit percent on the stock is  23800
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SM8cd9c281670e4bcfa9c333a0a824827c>
# Do you want to continue with same stock:(1/0)
# 0
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Welcome to Autonomus Cryptocurrency Exchange:
# The variety of Crypto-currency Available for Autonomus Alert System are:
# 1.Bitcoin [BTC]
# 2.Ethereum [ETH]
# 3.EOS [EOS]
# 4.Xrp [XRP]
# 5.Litecoin [LTC]
# 6.Okex [OKB]
# 7.Tron [TRX]
# Kindly choose your Crypto from 1-7
# 5
# Enter the rate of the crypto currency,you have purchase:
# 3380
# This is the current rate of LTC in INR
# 4484
# Your current Profit percent on the stock is  32
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SMce16336ea02a400c82b4115fa9c8713b>
# This is the current rate of LTC in INR
# 4483
# Your current Profit percent on the stock is  32
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SMf0d82dc0b87e407ba71ef01b74a4d160>
# This is the current rate of LTC in INR
# 4484
# Your current Profit percent on the stock is  32
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SMa22c81a0a3094b52a40b9a1fcdc876b1>
# This is the current rate of LTC in INR
# 4486
# Your current Profit percent on the stock is  32
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SM9339cd244d8a4ba895a405553ccd97de>
# This is the current rate of LTC in INR
# 4485
# Your current Profit percent on the stock is  32
# the response from Twilio:
# <Twilio.Api.V2010.MessageInstance account_sid=ACdb3ccdf73b4b17149e2d1a70a1c9bb46 sid=SM7d82b955b76348f295211a6065cff48c>
# Do you want to continue with same stock:(1/0)
# 0
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Welcome to Autonomus Cryptocurrency Exchange:
# The variety of Crypto-currency Available for Autonomus Alert System are:
# 1.Bitcoin [BTC]
# 2.Ethereum [ETH]
# 3.EOS [EOS]
# 4.Xrp [XRP]
# 5.Litecoin [LTC]
# 6.Okex [OKB]
# 7.Tron [TRX]
# Kindly choose your Crypto from 1-7
# 5
# Enter the rate of the crypto currency,you have purchase:
# 4125
# This is the current rate of LTC in INR
# 4486
# Your current Profit percent on the stock is  8
# the stock value is increased more than 5% higher than your rate
# {"value": "1", "success": 1}
# This is the current rate of LTC in INR
# 4485
# Your current Profit percent on the stock is  8
# the stock value is increased more than 5% higher than your rate
# {"value": "1", "success": 1}
# This is the current rate of LTC in INR
# 4486
# Your current Profit percent on the stock is  8
# the stock value is increased more than 5% higher than your rate
# {"value": "1", "success": 1}
# This is the current rate of LTC in INR
# 4486
# Your current Profit percent on the stock is  8
# the stock value is increased more than 5% higher than your rate
# {"value": "1", "success": 1}
# This is the current rate of LTC in INR
# 4486
# Your current Profit percent on the stock is  8
# the stock value is increased more than 5% higher than your rate
# {"value": "1", "success": 1}
# Do you want to continue with same stock:(1/0)
# 0
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Welcome to Autonomus Cryptocurrency Exchange:
# The variety of Crypto-currency Available for Autonomus Alert System are:
# 1.Bitcoin [BTC]
# 2.Ethereum [ETH]
# 3.EOS [EOS]
# 4.Xrp [XRP]
# 5.Litecoin [LTC]
# 6.Okex [OKB]
# 7.Tron [TRX]
# Kindly choose your Crypto from 1-7
# 5
# Enter the rate of the crypto currency,you have purchase:
# 4600
# This is the current rate of LTC in INR
# 4487
# Your loss percent is 2
# the prices of stock are not sufficient to exchange
# {"value": "1", "success": 1}
# This is the current rate of LTC in INR
# 4487
# Your loss percent is 2
# the prices of stock are not sufficient to exchange
# {"value": "1", "success": 1}
# This is the current rate of LTC in INR
# 4486
# Your loss percent is 2
# the prices of stock are not sufficient to exchange
# {"value": "1", "success": 1}
# This is the current rate of LTC in INR
# 4486
# Your loss percent is 2
# the prices of stock are not sufficient to exchange
# {"value": "1", "success": 1}
# This is the current rate of LTC in INR
# 4272
# Your loss percent is 7
# the prices of stock are not sufficient to exchange
# {"value": "1", "success": 1}
# Do you want to continue with same stock:(1/0)
